# %% [markdown]
# <h1 style = "color:green"><i>Iceland</i></h1>

# %%
# %%html
# <svg viewBox="0 0 22 16">
# <rect width="22" height="16" fill="#00205b"/>
# <g fill="#fff">
# <rect width="4" height="16" x="6"/>
# <rect width="22" height="4" y="6"/>
# </g>
# <g fill="#ba0c2f">
# <rect width="2" height="16" x="7"/>
# <rect width="22" height="2" y="7"/>
# </g>
# </svg>
# Out:
# <svg viewBox="0 0 22 16">
# <rect width="22" height="16" fill="#00205b"/>
# <g fill="#fff">
# <rect width="4" height="16" x="6"/>
# <rect width="22" height="4" y="6"/>
# </g>
# <g fill="#ba0c2f">
# <rect width="2" height="16" x="7"/>
# <rect width="22" height="2" y="7"/>
# </g>
# </svg>

# %% [markdown]
# <ul>
# <h3 style = "color:orange">Facts</h3>
# <li><strong>Capital and largest city : </strong><i>Reykjavík</i></li>
# <li><strong> President : </strong><i>Guðni Th. Jóhannesson </i></li>
# <li><strong> Official language and national language: </strong><i>Icelandic</i></li>
# <h3 style = "color:orange">Area</h3>
# <li><strong>Total : </strong><i>102,775 km2 </i></li>
# <li><strong> Water (%) : </strong><i>2.07</i></li>
# </ul>

# %% [markdown]
# <h1 style = "color:blue">History of Iceland</h3>
# <table style = "width:100%">
#     <tr>
#         <th>Timeline</th>
#         <th>Name</th>
#         <th>Owerview</th>
#     </tr>
#     <tr>
#         <td><strong>874 – 1262</strong></td>
#         <td><i>Settlement and Commonwealth</i></td>
#         <td>Commonwealth</td>
#     </tr>
#     <tr>
#         <td><strong>1262 - 1397</strong></td>
#         <td><i>The Middle Ages</i></td>
#         <td>Norwegian rule</td>
#     </tr>
#       <tr>
#         <td><strong>1397 - 1523</strong></td>
#         <td><i>The Middle Ages</i></td>
#         <td>Danish rule</td>
#     </tr>
#       <tr>
#         <td><strong>1523 - 1814</strong></td>
#         <td><i>Early Modern period</i></td>
#         <td>Danish rule</td>
#     </tr>
#      <tr>
#         <td><strong>1918 – 1944</strong></td>
#         <td><i>Independence and the Kingdom of Iceland</i></td>
#         <td>Icelandic independence movement</td>
#     </tr>
#      <tr>
#         <td><strong>1944 – present</strong></td>
#         <td><i>Republic of Iceland</i></td>
#         <td>Republic</td>
#     </tr>
#
# </table>

# %%
# %%html
# <style>
#         ul {
#             padding-left: 20px;
#         }
#
#         .landmarks {
#             padding: 30px;
#             border: 2px solid #ccc;
#             border-radius: 10px;
#             color: rgb(29, 122, 30);
#             min-width: 900px;
#         }
#
#         .landmark-section {
#             display: grid;
#             grid-row: 1;
#             row-gap: 20px;
#         }
#
#         .landmark {
#             padding: 20px 5px;
#             border: 1px solid #333;
#             border-radius: 15px;
#             color: rgb(155, 179, 22);
#             text-align: center;
#         }
#
#         .landmark img {
#             max-width: 800px;
#             border-radius: 100px;
#         }
# </style>
#
# <h2>Beautiful landmarks</h2>
#
# <div class="landmarks">
#     <ul>
#         <li>
#             <h3>Landmarks</h3>
#             <ul class="landmark-section">
#                 <li>
#                     <div class="landmark">
#                         <h3>Lanscape #1</h3>
#                         <img src="https://static.toiimg.com/photo/msid-79558557,width-96,height-65.cms"
#                             alt="Lanscape #1">
#                     </div>
#                 </li>
#                 <li>
#                     <div class="landmark">
#                         <h3>Lanscape #2</h3>
#                         <img src="https://www.planetware.com/wpimages/2020/01/iceland-in-pictures-beautiful-places-to-photograph-icelandic-countryside.jpg"
#                             alt="Lanscape #2">
#                     </div>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <h3>Landmarks</h3>
#             <ul class="landmark-section">
#                 <li>
#                     <div class="landmark">
#                         <h3>Beautiful image #1</h3>
#                         <img src="img/img1.webp">
#                     </div>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>
# Out:
# <style>
#         ul {
#             padding-left: 20px;
#         }
#
#         .landmarks {
#             padding: 30px;
#             border: 2px solid #ccc;
#             border-radius: 10px;
#             color: rgb(29, 122, 30);
#             min-width: 900px;
#         }
#
#         .landmark-section {
#             display: grid;
#             grid-row: 1;
#             row-gap: 20px;
#         }
#
#         .landmark {
#             padding: 20px 5px;
#             border: 1px solid #333;
#             border-radius: 15px;
#             color: rgb(155, 179, 22);
#             text-align: center;
#         }
#
#         .landmark img {
#             max-width: 800px;
#             border-radius: 100px;
#         }
# </style>
#
# <h2>Beautiful landmarks</h2>
#
# <div class="landmarks">
#     <ul>
#         <li>
#             <h3>Landmarks</h3>
#             <ul class="landmark-section">
#                 <li>
#                     <div class="landmark">
#                         <h3>Lanscape #1</h3>
#                         <img src="https://static.toiimg.com/photo/msid-79558557,width-96,height-65.cms"
#                             alt="Lanscape #1">
#                     </div>
#                 </li>
#                 <li>
#                     <div class="landmark">
#                         <h3>Lanscape #2</h3>
#                         <img src="https://res.cloudinary.com/sagacity/image/upload/c_crop,h_667,w_1000,x_0,y_0/c_limit,w_1080/v1433187536/shutterstock_199888055_xj76rw.jpg"
#                             alt="Lanscape #2">
#                     </div>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <h3>Landmarks</h3>
#             <ul class="landmark-section">
#                 <li>
#                     <div class="landmark">
#                         <h3>Beautiful image #1</h3>
#                         <img src="img/img1.webp">
#                     </div>
#                 </li>
#                 <li>
#                     <div class="landmark">
#                         <h3>Beautiful image #2</h3>
#                     </div>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>
